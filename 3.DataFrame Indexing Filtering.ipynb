# %%
import numpy as np
import pandas as pd

# %%
csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/country.csv'

# %%
df = pd.read_csv(csv_data_path)

# %%
df.columns #列出列名
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=227, step=1)

# %%
df.shape
# Out:
# (227, 20)

# %%
df['Country'] #获取特定列的数据
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
df['Country'].iloc[0]
# Out:
# 'Afghanistan'

# %%
df.iloc[3]
# Out:
# Country                                                    American Samoa
# Region                                OCEANIA
# Population                                                          57794
# Area (sq. mi.)                                                        199
# Pop. Density (per sq. mi.)                                          290,4
# Coastline (coast/area ratio)                                        58,29
# Net migration                                                      -20,71
# Infant mortality (per 1000 births)                                   9,27
# GDP ($ per capita)                                                 8000.0
# Literacy (%)                                                         97,0
# Phones (per 1000)                                                   259,5
# Arable (%)                                                             10
# Crops (%)                                                              15
# ...

# %%
df.iloc[11:20]
# Out:
#          Country                               Region  Population  \
# 11     Australia  OCEANIA                                20264082
# 12       Austria  WESTERN EUROPE                          8192880
# 13    Azerbaijan                 C.W. OF IND. STATES      7961619
# 14  Bahamas, The              LATIN AMER. & CARIB          303770
# 15       Bahrain  NEAR EAST                                698585
# 16    Bangladesh        ASIA (EX. NEAR EAST)            147365352
# 17      Barbados              LATIN AMER. & CARIB          279912
# 18       Belarus                 C.W. OF IND. STATES     10293011
# 19       Belgium  WESTERN EUROPE                         10379067
#
#     Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 11         7686850                        2,6                         0,34
# 12           83870                       97,7                         0,00
# 13           86600                       91,9                         0,00
# ...

# %%
df.loc[3]
# Out:
# Country                                                    American Samoa
# Region                                OCEANIA
# Population                                                          57794
# Area (sq. mi.)                                                        199
# Pop. Density (per sq. mi.)                                          290,4
# Coastline (coast/area ratio)                                        58,29
# Net migration                                                      -20,71
# Infant mortality (per 1000 births)                                   9,27
# GDP ($ per capita)                                                 8000.0
# Literacy (%)                                                         97,0
# Phones (per 1000)                                                   259,5
# Arable (%)                                                             10
# Crops (%)                                                              15
# ...

# %%
df.loc[0:3]
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# ...

# %%
df.iat[1,2]
# Out:
# 3581655

# %%
df.at[1, 'Population']
# Out:
# 3581655

# %%
df.iat[1, 2]
# Out:
# 3581655

# %%
df.set_index('Country') #将Country列为index
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=227, step=1)

# %%
df.set_index('Country', inplace = True)

# %%
df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua & Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Virgin Islands',
#        'Wallis and Futuna', 'West Bank', 'Western Sahara', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country', length=227)

# %%
df.loc[['China','Vietnam']]
# Out:
#                                 Region  Population  Area (sq. mi.)  \
# Country
# China    ASIA (EX. NEAR EAST)           1313973713         9596960
# Vietnam  ASIA (EX. NEAR EAST)             84402966          329560
#
#         Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# Country
# China                        136,9                         0,15          -0,4
# Vietnam                      256,1                         1,05         -0,45
#
#         Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# Country
# China                                24,18              5000.0         90,9
# Vietnam                              25,95              2500.0         90,3
#
#         Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# Country
# China               266,7       15,4      1,25     83,35     1,5     13,25
# Vietnam             187,7      19,97      5,95     74,08       2     16,86
#
# ...

# %%
df.loc[['China', 'Vietnam'], ['Region', 'Net migration']]
# Out:
#                                 Region Net migration
# Country
# China    ASIA (EX. NEAR EAST)                   -0,4
# Vietnam  ASIA (EX. NEAR EAST)                  -0,45

# %%
df.sort_index()
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df.sort_index(ascending = False)
# Out:
#                                              Region  Population  \
# Country
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Yemen           NEAR EAST                              21456188
# Western Sahara  NORTHERN AFRICA                          273008
# West Bank       NEAR EAST                               2460492
# ...                                             ...         ...
# Andorra         WESTERN EUROPE                            71201
# American Samoa  OCEANIA                                   57794
# Algeria         NORTHERN AFRICA                        32930091
# Albania         EASTERN EUROPE                          3581655
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Zimbabwe                390580                       31,3
# Zambia                  752614                       15,3
# ...

# %%
df.drop(['Zimbabwe','Yemen']).sort_index(ascending = False)
# Out:
#                                                 Region  Population  \
# Country
# Zambia             SUB-SAHARAN AFRICA                     11502010
# Western Sahara     NORTHERN AFRICA                          273008
# West Bank          NEAR EAST                               2460492
# Wallis and Futuna  OCEANIA                                   16025
# Virgin Islands                 LATIN AMER. & CARIB          108605
# ...                                                ...         ...
# Andorra            WESTERN EUROPE                            71201
# American Samoa     OCEANIA                                   57794
# Algeria            NORTHERN AFRICA                        32930091
# Albania            EASTERN EUROPE                          3581655
# Afghanistan              ASIA (EX. NEAR EAST)             31056997
#
#                    Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Zambia                     752614                       15,3
# ...

# %%
df.drop(['Region','Population'], axis = 1).sort_index(ascending = False)
# Out:
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Zimbabwe                390580                       31,3
# Zambia                  752614                       15,3
# Yemen                   527970                       40,6
# Western Sahara          266000                        1,0
# West Bank                 5860                      419,9
# ...                        ...                        ...
# Andorra                    468                      152,1
# American Samoa             199                      290,4
# Algeria                2381740                       13,8
# Albania                  28748                      124,6
# Afghanistan             647500                       48,0
#
#                Coastline (coast/area ratio) Net migration  \
# Country
# Zimbabwe                               0,00             0
# Zambia                                 0,00             0
# Yemen                                  0,36             0
# ...

# %%
df.reset_index()
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df.sort_values('Population', ascending=False).iloc[:10][['Region','Net migration']]
# Out:
#                                             Region Net migration
# Country
# China                ASIA (EX. NEAR EAST)                   -0,4
# India                ASIA (EX. NEAR EAST)                  -0,07
# United States  NORTHERN AMERICA                             3,41
# Indonesia            ASIA (EX. NEAR EAST)                      0
# Brazil                     LATIN AMER. & CARIB             -0,03
# Pakistan             ASIA (EX. NEAR EAST)                  -2,77
# Bangladesh           ASIA (EX. NEAR EAST)                  -0,71
# Russia                        C.W. OF IND. STATES           1,02
# Nigeria        SUB-SAHARAN AFRICA                           0,26
# Japan                ASIA (EX. NEAR EAST)                      0

# %%
df.columns
# Out:
# Index(['Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
#        'Coastline (coast/area ratio)', 'Net migration',
#        'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
#        'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
#        'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service'],
#       dtype='object')

# %%
df.rename(columns = {'Net migration':'Nm', 'Pop. Density (per sq. mi.)':'Pop'}, inplace=True)

# %%
df
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.)    Pop Coastline (coast/area ratio)      Nm  \
# Country
# Afghanistan             647500   48,0                         0,00   23,06
# ...

# %%
df['Nm'] == '0'
# Out:
# Country
# Afghanistan       False
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# West Bank         False
# Western Sahara    False
# Yemen              True
# Zambia             True
# Zimbabwe           True
# Name: Nm, Length: 227, dtype: bool

# %%
zero_migration_filter = df['Nm'] == '0'

# %%
df[zero_migration_filter]
# Out:
#                                        Region  Population  Area (sq. mi.)  \
# Country
# Angola    SUB-SAHARAN AFRICA                     12127071         1246700
# Aruba                 LATIN AMER. & CARIB           71891             193
# Belize                LATIN AMER. & CARIB          287730           22966
# Benin     SUB-SAHARAN AFRICA                      7862944          112620
# Bhutan          ASIA (EX. NEAR EAST)              2279723           47000
# ...                                       ...         ...             ...
# Uganda    SUB-SAHARAN AFRICA                     28195754          236040
# Vanuatu   OCEANIA                                  208869           12200
# Yemen     NEAR EAST                              21456188          527970
# Zambia    SUB-SAHARAN AFRICA                     11502010          752614
# Zimbabwe  SUB-SAHARAN AFRICA                     12236805          390580
#
#             Pop Coastline (coast/area ratio) Nm  \
# Country
# ...

# %%
df.loc[zero_migration_filter, ['Region','Pop','Nm']]
# Out:
#                                        Region    Pop Nm
# Country
# Angola    SUB-SAHARAN AFRICA                     9,7  0
# Aruba                 LATIN AMER. & CARIB      372,5  0
# Belize                LATIN AMER. & CARIB       12,5  0
# Benin     SUB-SAHARAN AFRICA                    69,8  0
# Bhutan          ASIA (EX. NEAR EAST)            48,5  0
# ...                                       ...    ... ..
# Uganda    SUB-SAHARAN AFRICA                   119,5  0
# Vanuatu   OCEANIA                               17,1  0
# Yemen     NEAR EAST                             40,6  0
# Zambia    SUB-SAHARAN AFRICA                    15,3  0
# Zimbabwe  SUB-SAHARAN AFRICA                    31,3  0
#
# [62 rows x 3 columns]
