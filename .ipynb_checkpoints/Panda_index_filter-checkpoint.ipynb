# %%
import pandas as pd
csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/country_info.csv'

# %%
df = pd.read_csv(csv_data_path)

# %%
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# Country                                                Afghanistan
# Region                                ASIA (EX. NEAR EAST)
# Population                                                 31056997
# Area (sq. mi.)                                               647500
# Pop. Density (per sq. mi.)                                     48,0
# Coastline (coast/area ratio)                                   0,00
# Net migration                                                 23,06
# Infant mortality (per 1000 births)                           163,07
# GDP ($ per capita)                                            700.0
# Literacy (%)                                                   36,0
# Phones (per 1000)                                               3,2
# Arable (%)                                                    12,13
# Crops (%)                                                      0,22
# Other (%)                                                     87,65
# ...

# %%
df.iloc[1]
# Out:
# Country                                                          Albania
# Region                                EASTERN EUROPE
# Population                                                        3581655
# Area (sq. mi.)                                                      28748
# Pop. Density (per sq. mi.)                                          124,6
# Coastline (coast/area ratio)                                         1,26
# Net migration                                                       -4,93
# Infant mortality (per 1000 births)                                  21,52
# GDP ($ per capita)                                                 4500.0
# Literacy (%)                                                         86,5
# Phones (per 1000)                                                    71,2
# Arable (%)                                                          21,09
# Crops (%)                                                            4,42
# ...

# %%
df.iloc[3:6]
# Out:
#            Country                               Region  Population  \
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
# 5          Angola   SUB-SAHARAN AFRICA                     12127071
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
# 5         1246700                        9,7                         0,13
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
# 5             0                             191,19              1900.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# ...

# %%
df['Country']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
df.set_index('Country')
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df['Country'] = df['Country'].str.strip() #把其中首位空格去掉
df.set_index('Country', inplace=True)

# %%
df
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df['Region']
# Out:
# Country
# Afghanistan             ASIA (EX. NEAR EAST)
# Albania           EASTERN EUROPE
# Algeria           NORTHERN AFRICA
# American Samoa    OCEANIA
# Andorra           WESTERN EUROPE
#                                  ...
# West Bank         NEAR EAST
# Western Sahara    NORTHERN AFRICA
# Yemen             NEAR EAST
# Zambia            SUB-SAHARAN AFRICA
# Zimbabwe          SUB-SAHARAN AFRICA
# Name: Region, Length: 227, dtype: object

# %%
df.loc['China']
# Out:
# Region                                ASIA (EX. NEAR EAST)
# Population                                               1313973713
# Area (sq. mi.)                                              9596960
# Pop. Density (per sq. mi.)                                    136,9
# Coastline (coast/area ratio)                                   0,15
# Net migration                                                  -0,4
# Infant mortality (per 1000 births)                            24,18
# GDP ($ per capita)                                           5000.0
# Literacy (%)                                                   90,9
# Phones (per 1000)                                             266,7
# Arable (%)                                                     15,4
# Crops (%)                                                      1,25
# Other (%)                                                     83,35
# Climate                                                         1,5
# ...

# %%
df.loc['China',['Industry', 'Climate']]
# Out:
# Industry    0,473
# Climate       1,5
# Name: China, dtype: object

# %%
df.iloc[0]
# Out:
# Region                                ASIA (EX. NEAR EAST)
# Population                                                 31056997
# Area (sq. mi.)                                               647500
# Pop. Density (per sq. mi.)                                     48,0
# Coastline (coast/area ratio)                                   0,00
# Net migration                                                 23,06
# Infant mortality (per 1000 births)                           163,07
# GDP ($ per capita)                                            700.0
# Literacy (%)                                                   36,0
# Phones (per 1000)                                               3,2
# Arable (%)                                                    12,13
# Crops (%)                                                      0,22
# Other (%)                                                     87,65
# Climate                                                           1
# ...

# %%
df.iloc[1]
# Out:
# Region                                EASTERN EUROPE
# Population                                                        3581655
# Area (sq. mi.)                                                      28748
# Pop. Density (per sq. mi.)                                          124,6
# Coastline (coast/area ratio)                                         1,26
# Net migration                                                       -4,93
# Infant mortality (per 1000 births)                                  21,52
# GDP ($ per capita)                                                 4500.0
# Literacy (%)                                                         86,5
# Phones (per 1000)                                                    71,2
# Arable (%)                                                          21,09
# Crops (%)                                                            4,42
# Other (%)                                                           74,49
# ...

# %%
df.sort_index()
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df.sort_index(ascending = False)
# Out:
#                                              Region  Population  \
# Country
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Yemen           NEAR EAST                              21456188
# Western Sahara  NORTHERN AFRICA                          273008
# West Bank       NEAR EAST                               2460492
# ...                                             ...         ...
# Andorra         WESTERN EUROPE                            71201
# American Samoa  OCEANIA                                   57794
# Algeria         NORTHERN AFRICA                        32930091
# Albania         EASTERN EUROPE                          3581655
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Zimbabwe                390580                       31,3
# Zambia                  752614                       15,3
# ...

# %%
df
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df.drop(['Zimbabwe','Yemen'], axis = 0) #将国家名为Zimbabwe和Yemen的数据删除掉，axis = 0 代表根据行来定位数据
# Out:
#                                                 Region  Population  \
# Country
# Afghanistan              ASIA (EX. NEAR EAST)             31056997
# Albania            EASTERN EUROPE                          3581655
# Algeria            NORTHERN AFRICA                        32930091
# American Samoa     OCEANIA                                   57794
# Andorra            WESTERN EUROPE                            71201
# ...                                                ...         ...
# Virgin Islands                 LATIN AMER. & CARIB          108605
# Wallis and Futuna  OCEANIA                                   16025
# West Bank          NEAR EAST                               2460492
# Western Sahara     NORTHERN AFRICA                          273008
# Zambia             SUB-SAHARAN AFRICA                     11502010
#
#                    Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan                647500                       48,0
# ...

# %%
df.drop(['Region', 'Population'], axis = 1) # 将Region和Population两列的数据全部删除，axis = 1 代表根据列来定位数据
# Out:
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# Algeria                2381740                       13,8
# American Samoa             199                      290,4
# Andorra                    468                      152,1
# ...                        ...                        ...
# West Bank                 5860                      419,9
# Western Sahara          266000                        1,0
# Yemen                   527970                       40,6
# Zambia                  752614                       15,3
# Zimbabwe                390580                       31,3
#
#                Coastline (coast/area ratio) Net migration  \
# Country
# Afghanistan                            0,00         23,06
# Albania                                1,26         -4,93
# Algeria                                0,04         -0,39
# ...

# %%
df.reset_index()
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                       48,0
# Albania                  28748                      124,6
# ...

# %%
df['Net migration'] == 0
# Out:
# Country
# Afghanistan       False
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# West Bank         False
# Western Sahara    False
# Yemen             False
# Zambia            False
# Zimbabwe          False
# Name: Net migration, Length: 227, dtype: bool

# %%
zero_migration_filter = (df['Net migration'] == '0')

# %%
zero_migration_filter
# Out:
# Country
# Afghanistan       False
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# West Bank         False
# Western Sahara    False
# Yemen              True
# Zambia             True
# Zimbabwe           True
# Name: Net migration, Length: 227, dtype: bool

# %%
df[zero_migration_filter] # 获得所有0净迁移率国家的数据
# Out:
#                                        Region  Population  Area (sq. mi.)  \
# Country
# Angola    SUB-SAHARAN AFRICA                     12127071         1246700
# Aruba                 LATIN AMER. & CARIB           71891             193
# Belize                LATIN AMER. & CARIB          287730           22966
# Benin     SUB-SAHARAN AFRICA                      7862944          112620
# Bhutan          ASIA (EX. NEAR EAST)              2279723           47000
# ...                                       ...         ...             ...
# Uganda    SUB-SAHARAN AFRICA                     28195754          236040
# Vanuatu   OCEANIA                                  208869           12200
# Yemen     NEAR EAST                              21456188          527970
# Zambia    SUB-SAHARAN AFRICA                     11502010          752614
# Zimbabwe  SUB-SAHARAN AFRICA                     12236805          390580
#
#          Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df[~zero_migration_filter] # 获得所有非净迁移率0国家的数据
# Out:
#                                                 Region  Population  \
# Country
# Afghanistan              ASIA (EX. NEAR EAST)             31056997
# Albania            EASTERN EUROPE                          3581655
# Algeria            NORTHERN AFRICA                        32930091
# American Samoa     OCEANIA                                   57794
# Andorra            WESTERN EUROPE                            71201
# ...                                                ...         ...
# Vietnam                  ASIA (EX. NEAR EAST)             84402966
# Virgin Islands                 LATIN AMER. & CARIB          108605
# Wallis and Futuna  OCEANIA                                   16025
# West Bank          NEAR EAST                               2460492
# Western Sahara     NORTHERN AFRICA                          273008
#
#                    Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan                647500                       48,0
# ...

# %%
df.loc[~zero_migration_filter, ['Region', 'Population', 'Birthrate']] # # 只查看非0净迁移率国家的Region和Populatino列
# Out:
#                                                 Region  Population Birthrate
# Country
# Afghanistan              ASIA (EX. NEAR EAST)             31056997      46,6
# Albania            EASTERN EUROPE                          3581655     15,11
# Algeria            NORTHERN AFRICA                        32930091     17,14
# American Samoa     OCEANIA                                   57794     22,46
# Andorra            WESTERN EUROPE                            71201      8,71
# ...                                                ...         ...       ...
# Vietnam                  ASIA (EX. NEAR EAST)             84402966     16,86
# Virgin Islands                 LATIN AMER. & CARIB          108605     13,96
# Wallis and Futuna  OCEANIA                                   16025       NaN
# West Bank          NEAR EAST                               2460492     31,67
# Western Sahara     NORTHERN AFRICA                          273008       NaN
#
# [165 rows x 3 columns]

# %%
low_migration_filter = (df['Net migration'] < '100')
df.loc[low_migration_filter, ['Region', 'Population']] # 查看净迁移率小于100的国家信息
# Out:
#                                              Region  Population
# Country
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Angola          SUB-SAHARAN AFRICA                     12127071
# Anguilla                    LATIN AMER. & CARIB           13477
# ...                                             ...         ...
# Vietnam               ASIA (EX. NEAR EAST)             84402966
# Virgin Islands              LATIN AMER. & CARIB          108605
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
# [182 rows x 2 columns]

# %%
df[low_migration_filter]
# Out:
#                                              Region  Population  \
# Country
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Angola          SUB-SAHARAN AFRICA                     12127071
# Anguilla                    LATIN AMER. & CARIB           13477
# ...                                             ...         ...
# Vietnam               ASIA (EX. NEAR EAST)             84402966
# Virgin Islands              LATIN AMER. & CARIB          108605
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Albania                  28748                      124,6
# Algeria                2381740                       13,8
# ...

# %%
df.loc[low_migration_filter, ['Region']]
# Out:
#                                              Region
# Country
# Albania         EASTERN EUROPE
# Algeria         NORTHERN AFRICA
# American Samoa  OCEANIA
# Angola          SUB-SAHARAN AFRICA
# Anguilla                    LATIN AMER. & CARIB
# ...                                             ...
# Vietnam               ASIA (EX. NEAR EAST)
# Virgin Islands              LATIN AMER. & CARIB
# Yemen           NEAR EAST
# Zambia          SUB-SAHARAN AFRICA
# Zimbabwe        SUB-SAHARAN AFRICA
#
# [182 rows x 1 columns]

# %%
df.loc["China"]
# Out:
# Region                                ASIA (EX. NEAR EAST)
# Population                                               1313973713
# Area (sq. mi.)                                              9596960
# Pop. Density (per sq. mi.)                                    136,9
# Coastline (coast/area ratio)                                   0,15
# Net migration                                                  -0,4
# Infant mortality (per 1000 births)                            24,18
# GDP ($ per capita)                                           5000.0
# Literacy (%)                                                   90,9
# Phones (per 1000)                                             266,7
# Arable (%)                                                     15,4
# Crops (%)                                                      1,25
# Other (%)                                                     83,35
# Climate                                                         1,5
# ...

# %%
df['Region']
# Out:
# Country
# Afghanistan             ASIA (EX. NEAR EAST)
# Albania           EASTERN EUROPE
# Algeria           NORTHERN AFRICA
# American Samoa    OCEANIA
# Andorra           WESTERN EUROPE
#                                  ...
# West Bank         NEAR EAST
# Western Sahara    NORTHERN AFRICA
# Yemen             NEAR EAST
# Zambia            SUB-SAHARAN AFRICA
# Zimbabwe          SUB-SAHARAN AFRICA
# Name: Region, Length: 227, dtype: object

# %%
df[['Deathrate', 'Population']]
# Out:
#                Deathrate  Population
# Country
# Afghanistan        20,34    31056997
# Albania             5,22     3581655
# Algeria             4,61    32930091
# American Samoa      3,27       57794
# Andorra             6,25       71201
# ...                  ...         ...
# West Bank           3,92     2460492
# Western Sahara       NaN      273008
# Yemen                8,3    21456188
# Zambia             19,93    11502010
# Zimbabwe           21,84    12236805
#
# [227 rows x 2 columns]

# %%
and_filter = (df['Deathrate'] > '1000') & (df['Population'] < 10000) #AND条件，同时满足Deathrate大于'1000'，人口小于 10000

# %%
df.loc[and_filter, 'Region']
# Out:
# Country
# Montserrat                          LATIN AMER. & CARIB
# Saint Helena            SUB-SAHARAN AFRICA
# St Pierre & Miquelon    NORTHERN AMERICA
# Name: Region, dtype: object

# %%
df['Deathrate']
# Out:
# Country
# Afghanistan       20,34
# Albania            5,22
# Algeria            4,61
# American Samoa     3,27
# Andorra            6,25
#                   ...
# West Bank          3,92
# Western Sahara      NaN
# Yemen               8,3
# Zambia            19,93
# Zimbabwe          21,84
# Name: Deathrate, Length: 227, dtype: object

# %%
countries = ['China', 'Japan', 'United States', 'India']

# %%
df.loc[countries, ['Region']]
# Out:
#                                             Region
# Country
# China                ASIA (EX. NEAR EAST)
# Japan                ASIA (EX. NEAR EAST)
# United States  NORTHERN AMERICA
# India                ASIA (EX. NEAR EAST)

# %%
df.loc[countries, ["Population", 'Region']]
# Out:
#                Population                               Region
# Country
# China          1313973713        ASIA (EX. NEAR EAST)
# Japan           127463611        ASIA (EX. NEAR EAST)
# United States   298444215  NORTHERN AMERICA
# India          1095351995        ASIA (EX. NEAR EAST)

# %%
df.reset_index(inplace = True)
str_filter = df['Country'].str.contains('A')
df.loc[~str_filter, 'Country'] # 获得所有国家名字中不包含字母A的国家名
# Out:
# 14       Bahamas, The
# 15            Bahrain
# 16         Bangladesh
# 17           Barbados
# 18            Belarus
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 208, dtype: object

# %%
str_filter2 = df['Country'].str.contains('A|Z')
df.loc[~str_filter2, 'Country'] # 获得所有国家名字中既不包含A也不包含Z的国家名
# Out:
# 14          Bahamas, The
# 15               Bahrain
# 16            Bangladesh
# 17              Barbados
# 18               Belarus
#              ...
# 220       Virgin Islands
# 221    Wallis and Futuna
# 222            West Bank
# 223       Western Sahara
# 224                Yemen
# Name: Country, Length: 205, dtype: object

# %%
str_filter2 = df['Country'].str.contains('A|B|C|D|E|F|G')
df.loc[~str_filter2, 'Country'] # 获得所有国家名字中不包含A到G的国家名
# Out:
# 89              Haiti
# 90           Honduras
# 91          Hong Kong
# 92            Hungary
# 93            Iceland
#             ...
# 220    Virgin Islands
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 127, dtype: object

# %%
str_filter3 = df['Country'].str.contains('[a-m]')
df.loc[~str_filter3, 'Country'] # 获得国家名中不包含小写字母a到m的国家名
# Out:
# 52    Cyprus
# Name: Country, dtype: object

# %%
str_filter3 = df['Country'].str.contains('[A-Y]')
df.loc[~str_filter3, 'Country'] # 获得国家名中不包含大写字母A到 Y的国家名
# Out:
# 225      Zambia
# 226    Zimbabwe
# Name: Country, dtype: object

# %%
#作业：
#只获取Population大于10000且Climate大于3的国家

# %%
home_work_filter = (df['Population'] > 10000) & (df['Climate'] > '3')

# %%
df.loc[home_work_filter, ['Country', 'Population', 'Climate']].set_index(['Country'])
# Out:
#                       Population Climate
# Country
# Armenia                  2976372       4
# Belarus                 10293011       4
# Bosnia & Herzegovina     4498976       4
# France                  60876136       4
# Kazakhstan              15233244       4
# Liechtenstein              33987       4

# %%
df.loc[home_work_filter, ['Country', 'Population', 'Climate']]
# Out:
#                   Country  Population Climate
# 9                 Armenia     2976372       4
# 18                Belarus    10293011       4
# 25   Bosnia & Herzegovina     4498976       4
# 69                 France    60876136       4
# 106            Kazakhstan    15233244       4
# 119         Liechtenstein       33987       4

# %%
df.loc[home_work_filter, ['Country', 'Population', 'Climate']].plot(x='Country', y='Population')
# Out:
# <Axes: xlabel='Country'>
