# %%
import numpy as np
import pandas as pd

# %%
file = 'my_workbook.xlsx'

# %%
df = pd.read_excel(file)

# %%
df
# Out:
#            日期                  1 张                  2 王                  3 李  \
# 0         NaT  2023-11-11 00:00:00  2023-11-02 00:00:00  2023-10-02 00:00:00
# 1         NaT                   病1                   病2                   病3
# 2  2023-11-01                   a1                   b2                   c3
# 3  2023-11-02                   a2                   b3                   c4
# 4  2023-11-03                   a3                   b4                   c5
# 5  2023-11-04                   a4                   b5                   c6
# 6  2023-11-05                   a5                   b6                   c7
# 7  2023-11-06                   a6                   b7                   c8
# 8  2023-11-07                   a7                   b8                   c9
# 9  2023-11-08                   a8                   b9                  c10
# 10 2023-11-09                   a9                  b10                  c11
# ...

# %%
df.shape
# Out:
# (24, 9)
