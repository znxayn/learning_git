# %%
import pandas as pd
import numpy as np
csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/small_survey_results.csv'
survey_df = pd.read_csv(csv_data_path)

# %%
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0         20900  I am a developer by profession      Yes   NaN         10
# 1         28235  I am a developer by profession       No  45.0         10
# 2         26082  I am a developer by profession      Yes  23.0         14
# 3         19890  I am a developer by profession      Yes  61.0         21
# 4         16393  I am a developer by profession      Yes  25.0         15
# ..          ...                             ...      ...   ...        ...
# 995       51360  I am a developer by profession      Yes  26.0         13
# 996       16771  I am a developer by profession      Yes   NaN         11
# 997       38831  I am a developer by profession      Yes   NaN        NaN
# 998        7093  I am a developer by profession      Yes   NaN        NaN
# 999       51843  I am a developer by profession      Yes  29.0         20
#
#     CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# ...

# %%
survey_df.set_index('Respondent', inplace = True) #将Respondent设为index

# %%
survey_df
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 20900       I am a developer by profession      Yes   NaN         10  Monthly
# 28235       I am a developer by profession       No  45.0         10  Monthly
# 26082       I am a developer by profession      Yes  23.0         14   Yearly
# 19890       I am a developer by profession      Yes  61.0         21      NaN
# 16393       I am a developer by profession      Yes  25.0         15   Weekly
# ...                                    ...      ...   ...        ...      ...
# 51360       I am a developer by profession      Yes  26.0         13  Monthly
# 16771       I am a developer by profession      Yes   NaN         11      NaN
# 38831       I am a developer by profession      Yes   NaN        NaN      NaN
# 7093        I am a developer by profession      Yes   NaN        NaN      NaN
# 51843       I am a developer by profession      Yes  29.0         20  Monthly
#
# ...

# %%
survey_df.sort_index() #按照index进行排序，从小到大
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 59                             I am a developer by profession       No  38.0
# 146                            I am a developer by profession      Yes  33.0
# 167                            I am a developer by profession      Yes  22.0
# 237                            I am a developer by profession      Yes  26.0
# 275                            I am a developer by profession       No   NaN
# ...                                                       ...      ...   ...
# 65107                  I am a student who is learning to code      Yes   NaN
# 65198                  I am a student who is learning to code      Yes   NaN
# 65375                          I am a developer by profession      Yes   NaN
# 65628                          I am a developer by profession      Yes   NaN
# 65633       I used to be a developer by profession, but no...       No   NaN
#
# ...

# %%
survey_df.sort_index(ascending = False) #按照index进行排序，从大到小
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 65633       I used to be a developer by profession, but no...       No   NaN
# 65628                          I am a developer by profession      Yes   NaN
# 65375                          I am a developer by profession      Yes   NaN
# 65198                  I am a student who is learning to code      Yes   NaN
# 65107                  I am a student who is learning to code      Yes   NaN
# ...                                                       ...      ...   ...
# 275                            I am a developer by profession       No   NaN
# 237                            I am a developer by profession      Yes  26.0
# 167                            I am a developer by profession      Yes  22.0
# 146                            I am a developer by profession      Yes  33.0
# 59                             I am a developer by profession       No  38.0
#
# ...

# %%
survey_df.sort_values(by = 'Age', ascending=True)
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 59748       I am a student who is learning to code      Yes  13.0         10
# 23837       I am a student who is learning to code      Yes  15.0          9
# 11615       I am a student who is learning to code      Yes  15.0         14
# 4656        I am a student who is learning to code      Yes  15.0         13
# 29215       I am a student who is learning to code      Yes  15.0         10
# ...                                            ...      ...   ...        ...
# 275                 I am a developer by profession       No   NaN         18
# 63802               I am a developer by profession      Yes   NaN         20
# 16771               I am a developer by profession      Yes   NaN         11
# 38831               I am a developer by profession      Yes   NaN        NaN
# 7093                I am a developer by profession      Yes   NaN        NaN
#
# ...

# %%
survey_df.sort_values(by=['Age', 'YearsCode'], ascending=False)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 36576                          I am a developer by profession      Yes  67.0
# 56924       I used to be a developer by profession, but no...      Yes  63.0
# 3251                              I code primarily as a hobby      Yes  62.0
# 43830                          I am a developer by profession      Yes  61.0
# 57451                          I am a developer by profession       No  61.0
# ...                                                       ...      ...   ...
# 45154                          I am a developer by profession      Yes   NaN
# 59877                          I am a developer by profession      Yes   NaN
# 64744                          I am a developer by profession      Yes   NaN
# 38831                          I am a developer by profession      Yes   NaN
# 7093                           I am a developer by profession      Yes   NaN
#
# ...

# %%
survey_df.sort_values(by=['Age', 'YearsCode'], ascending=False)[['Age', 'YearsCode']]
# Out:
#              Age YearsCode
# Respondent
# 36576       67.0        50
# 56924       63.0        35
# 3251        62.0         3
# 43830       61.0        43
# 57451       61.0        42
# ...          ...       ...
# 45154        NaN       NaN
# 59877        NaN       NaN
# 64744        NaN       NaN
# 38831        NaN       NaN
# 7093         NaN       NaN
#
# [1000 rows x 2 columns]

# %%
survey_df.sort_values(by=['Age', 'YearsCode'], ascending=[False, True]).head(10)[['Age', 'YearsCode']]
# Out:
#              Age YearsCode
# Respondent
# 36576       67.0        50
# 56924       63.0        35
# 3251        62.0         3
# 19890       61.0        39
# 57451       61.0        42
# 43830       61.0        43
# 15907       59.0        35
# 31302       59.0        43
# 49614       58.0        42
# 14140       57.0        22

# %%
survey_df.sort_values(by=['Age', 'YearsCode'], ascending=[False, False]).head(10)[['Age', 'YearsCode']]
# Out:
#              Age YearsCode
# Respondent
# 36576       67.0        50
# 56924       63.0        35
# 3251        62.0         3
# 43830       61.0        43
# 57451       61.0        42
# 19890       61.0        39
# 31302       59.0        43
# 15907       59.0        35
# 49614       58.0        42
# 592         57.0        41

# %%
#如果需要改变原来的数据，加上 inplace=True

# %%
survey_df['Age'].sort_values() # 将单列内容进行排序
# Out:
# Respondent
# 59748    13.0
# 23837    15.0
# 11615    15.0
# 4656     15.0
# 29215    15.0
#          ...
# 275       NaN
# 63802     NaN
# 16771     NaN
# 38831     NaN
# 7093      NaN
# Name: Age, Length: 1000, dtype: float64

# %%
survey_df['ConvertedComp'].nlargest(10) # 前10名工资最高的用户工资信息
# Out:
# Respondent
# 29378    1000000.0
# 48807    1000000.0
# 18603     946944.0
# 5292      907572.0
# 28235     867480.0
# 19800     863316.0
# 47454     843168.0
# 21172     801720.0
# 59314     753936.0
# 26443     744000.0
# Name: ConvertedComp, dtype: float64

# %%
survey_df['ConvertedComp'].nsmallest(10) # 工资最低的前十名用户工资信息
# Out:
# Respondent
# 56562       0.0
# 50800    1164.0
# 35324    1512.0
# 60592    1644.0
# 9451     1944.0
# 34102    2064.0
# 63944    2340.0
# 6992     2520.0
# 62991    2556.0
# 48554    2844.0
# Name: ConvertedComp, dtype: float64

# %%
richest_users = survey_df.nlargest(10, 'ConvertedComp')#获取最富有的10个人的信息

# %%
richest_users
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 29378       I am not primarily a developer, but I write co...      Yes  36.0
# 48807       I am not primarily a developer, but I write co...      Yes   NaN
# 18603                          I am a developer by profession      Yes  30.0
# 5292        I am not primarily a developer, but I write co...      Yes  33.0
# 28235                          I am a developer by profession       No  45.0
# 19800                          I am a developer by profession      Yes   NaN
# 47454                          I am a developer by profession      Yes  35.0
# 21172                          I am a developer by profession      Yes  39.0
# 59314                          I am a developer by profession      Yes  32.0
# 26443                          I am a developer by profession      Yes  23.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# Respondent
# ...

# %%
richest_users[['ConvertedComp', 'DevType', 'EdLevel']] # 查看这些用户的工资、开发类型和教育程度
# Out:
#             ConvertedComp                                            DevType  \
# Respondent
# 29378           1000000.0  Data or business analyst;Data scientist or mac...
# 48807           1000000.0                                                NaN
# 18603            946944.0         Database administrator;Developer, back-end
# 5292             907572.0                                Developer, back-end
# 28235            867480.0                                  Developer, mobile
# 19800            863316.0           Developer, back-end;Developer, front-end
# 47454            843168.0  Developer, back-end;Developer, full-stack;Deve...
# 21172            801720.0  Developer, back-end;Developer, front-end;Devel...
# 59314            753936.0  Data scientist or machine learning specialist;...
# 26443            744000.0  Developer, back-end;Developer, desktop or ente...
#
#                                                       EdLevel
# Respondent
# ...

# %%
poorest_users = survey_df.nsmallest(10, 'ConvertedComp')

# %%
poorest_users
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 56562                          I am a developer by profession      Yes  25.0
# 50800                          I am a developer by profession      Yes   NaN
# 35324                          I am a developer by profession      Yes  26.0
# 60592                          I am a developer by profession      Yes  34.0
# 9451                           I am a developer by profession      Yes  31.0
# 34102       I am not primarily a developer, but I write co...      Yes  22.0
# 63944                          I am a developer by profession      Yes   NaN
# 6992                           I am a developer by profession      Yes  22.0
# 62991       I am not primarily a developer, but I write co...      Yes   NaN
# 48554                          I am a developer by profession       No  21.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp      Country  \
# Respondent
# ...

# %%
poorest_users[['ConvertedComp', 'DevType', 'EdLevel']] # 查看这些用户的工资、开发类型和教育程度
# Out:
#             ConvertedComp                                            DevType  \
# Respondent
# 56562                 0.0  Developer, back-end;Developer, front-end;Devel...
# 50800              1164.0  Developer, back-end;Developer, desktop or ente...
# 35324              1512.0  Data or business analyst;Data scientist or mac...
# 60592              1644.0  Data or business analyst;Database administrato...
# 9451               1944.0  Developer, back-end;Developer, front-end;Devel...
# 34102              2064.0                                Developer, back-end
# 63944              2340.0                       Developer, back-end;Educator
# 6992               2520.0  Developer, back-end;Developer, front-end;Devel...
# 62991              2556.0  Academic researcher;Developer, desktop or ente...
# 48554              2844.0  Academic researcher;Designer;Developer, back-e...
#
#                                                     EdLevel
# Respondent
# ...

# %%
# 章节地址：https://turingplanet.org/2021/05/05/pandas-intro4/

# %%
for col_name, col_data in survey_df.items(): #迭代列
    print(col_name) #打印列名
    print(col_data) #打印列上的数据
    break
# Out:
# MainBranch
# Respondent
# 20900    I am a developer by profession
# 28235    I am a developer by profession
# 26082    I am a developer by profession
# 19890    I am a developer by profession
# 16393    I am a developer by profession
#                       ...
# 51360    I am a developer by profession
# 16771    I am a developer by profession
# 38831    I am a developer by profession
# 7093     I am a developer by profession
# 51843    I am a developer by profession
# Name: MainBranch, Length: 1000, dtype: object

# %%
for row_index, row_info in survey_df.iterrows(): #迭代行
    print(row_index)
    print(row_info)
    break
# Out:
# 20900
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     10
# CompFreq                                                                  Monthly
# CompTotal                                                                  8000.0
# ConvertedComp                                                             53040.0
# Country                                                                  Bulgaria
# CurrencyDesc                                                        Bulgarian lev
# CurrencySymbol                                                                BGN
# DatabaseDesireNextYear                                            Cassandra;Redis
# ...

# %%
inversed_df = pd.DataFrame({idx: values for idx, values in survey_df.iterrows()}) #转置矩阵，行变为列
inversed_df
# Out:
#                                                                           20900  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                         NaN
# Age1stCode                                                                   10
# CompFreq                                                                Monthly
# CompTotal                                                                8000.0
# ConvertedComp                                                           53040.0
# Country                                                                Bulgaria
# CurrencyDesc                                                      Bulgarian lev
# CurrencySymbol                                                              BGN
# DatabaseDesireNextYear                                          Cassandra;Redis
# ...

# %%
survey_df
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 20900       I am a developer by profession      Yes   NaN         10  Monthly
# 28235       I am a developer by profession       No  45.0         10  Monthly
# 26082       I am a developer by profession      Yes  23.0         14   Yearly
# 19890       I am a developer by profession      Yes  61.0         21      NaN
# 16393       I am a developer by profession      Yes  25.0         15   Weekly
# ...                                    ...      ...   ...        ...      ...
# 51360       I am a developer by profession      Yes  26.0         13  Monthly
# 16771       I am a developer by profession      Yes   NaN         11      NaN
# 38831       I am a developer by profession      Yes   NaN        NaN      NaN
# 7093        I am a developer by profession      Yes   NaN        NaN      NaN
# 51843       I am a developer by profession      Yes  29.0         20  Monthly
#
# ...

# %%
survey_df.reset_index(inplace=True)

# %%
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0         20900  I am a developer by profession      Yes   NaN         10
# 1         28235  I am a developer by profession       No  45.0         10
# 2         26082  I am a developer by profession      Yes  23.0         14
# 3         19890  I am a developer by profession      Yes  61.0         21
# 4         16393  I am a developer by profession      Yes  25.0         15
# ..          ...                             ...      ...   ...        ...
# 995       51360  I am a developer by profession      Yes  26.0         13
# 996       16771  I am a developer by profession      Yes   NaN         11
# 997       38831  I am a developer by profession      Yes   NaN        NaN
# 998        7093  I am a developer by profession      Yes   NaN        NaN
# 999       51843  I am a developer by profession      Yes  29.0         20
#
#     CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# ...

# %%
survey_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_df.shape
# Out:
# (1000, 61)

# %%
survey_df.rename(columns = {'Age': 'user age', 'OrgSize': 'Organization Size'}, inplace=True)
# 转换列名（Age => user age，OrgSize => Organization Size)

# %%
survey_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'user age', 'Age1stCode',
#        'CompFreq', 'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'Organization Size', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_df.columns = survey_df.columns.str.replace(' ', '_')
# 将列名中的空格换成下划线

# %%
survey_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'user_age', 'Age1stCode',
#        'CompFreq', 'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'Organization_Size', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_df.columns = survey_df.columns.str.lower()
# 将列名全部小写

# %%
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
survey_df.columns =  [col.upper() for col in survey_df.columns]
# 另外一种改变列名大小写的方式

# %%
survey_df.columns
# Out:
# Index(['RESPONDENT', 'MAINBRANCH', 'HOBBYIST', 'USER_AGE', 'AGE1STCODE',
#        'COMPFREQ', 'COMPTOTAL', 'CONVERTEDCOMP', 'COUNTRY', 'CURRENCYDESC',
#        'CURRENCYSYMBOL', 'DATABASEDESIRENEXTYEAR', 'DATABASEWORKEDWITH',
#        'DEVTYPE', 'EDLEVEL', 'EMPLOYMENT', 'ETHNICITY', 'GENDER', 'JOBFACTORS',
#        'JOBSAT', 'JOBSEEK', 'LANGUAGEDESIRENEXTYEAR', 'LANGUAGEWORKEDWITH',
#        'MISCTECHDESIRENEXTYEAR', 'MISCTECHWORKEDWITH',
#        'NEWCOLLABTOOLSDESIRENEXTYEAR', 'NEWCOLLABTOOLSWORKEDWITH', 'NEWDEVOPS',
#        'NEWDEVOPSIMPT', 'NEWEDIMPT', 'NEWJOBHUNT', 'NEWJOBHUNTRESEARCH',
#        'NEWLEARN', 'NEWOFFTOPIC', 'NEWONBOARDGOOD', 'NEWOTHERCOMMS',
#        'NEWOVERTIME', 'NEWPURCHASERESEARCH', 'NEWPURPLELINK', 'NEWSOSITES',
#        'NEWSTUCK', 'OPSYS', 'ORGANIZATION_SIZE', 'PLATFORMDESIRENEXTYEAR',
#        'PLATFORMWORKEDWITH', 'PURCHASEWHAT', 'SEXUALITY', 'SOACCOUNT',
#        'SOCOMM', 'SOPARTFREQ', 'SOVISITFREQ', 'SURVEYEASE', 'SURVEYLENGTH',
# ...

# %%
survey_df.columns = survey_df.columns.str.capitalize()
# 将列标题改为首字母大写
survey_df.columns
# Out:
# Index(['Respondent', 'Mainbranch', 'Hobbyist', 'User_age', 'Age1stcode',
#        'Compfreq', 'Comptotal', 'Convertedcomp', 'Country', 'Currencydesc',
#        'Currencysymbol', 'Databasedesirenextyear', 'Databaseworkedwith',
#        'Devtype', 'Edlevel', 'Employment', 'Ethnicity', 'Gender', 'Jobfactors',
#        'Jobsat', 'Jobseek', 'Languagedesirenextyear', 'Languageworkedwith',
#        'Misctechdesirenextyear', 'Misctechworkedwith',
#        'Newcollabtoolsdesirenextyear', 'Newcollabtoolsworkedwith', 'Newdevops',
#        'Newdevopsimpt', 'Newedimpt', 'Newjobhunt', 'Newjobhuntresearch',
#        'Newlearn', 'Newofftopic', 'Newonboardgood', 'Newothercomms',
#        'Newovertime', 'Newpurchaseresearch', 'Newpurplelink', 'Newsosites',
#        'Newstuck', 'Opsys', 'Organization_size', 'Platformdesirenextyear',
#        'Platformworkedwith', 'Purchasewhat', 'Sexuality', 'Soaccount',
#        'Socomm', 'Sopartfreq', 'Sovisitfreq', 'Surveyease', 'Surveylength',
# ...

# %%
survey_df['Jobseek'].str.upper()
# Out:
# 0      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 1      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 2      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 3      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 4      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
#                              ...
# 995    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 996         I AM NOT INTERESTED IN NEW JOB OPPORTUNITIES
# 997                                                  NaN
# 998                      I AM ACTIVELY LOOKING FOR A JOB
# 999    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# Name: Jobseek, Length: 1000, dtype: object

# %%
survey_df['Jobseek']
# Out:
# 0      I’m not actively looking, but I am open to new...
# 1      I’m not actively looking, but I am open to new...
# 2      I’m not actively looking, but I am open to new...
# 3      I’m not actively looking, but I am open to new...
# 4      I’m not actively looking, but I am open to new...
#                              ...
# 995    I’m not actively looking, but I am open to new...
# 996         I am not interested in new job opportunities
# 997                                                  NaN
# 998                      I am actively looking for a job
# 999    I’m not actively looking, but I am open to new...
# Name: Jobseek, Length: 1000, dtype: object

# %%
survey_df['Jobseek'] = survey_df['Jobseek'].str.upper()
#将变化应用到原数据
survey_df['Jobseek']
# Out:
# 0      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 1      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 2      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 3      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 4      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
#                              ...
# 995    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 996         I AM NOT INTERESTED IN NEW JOB OPPORTUNITIES
# 997                                                  NaN
# 998                      I AM ACTIVELY LOOKING FOR A JOB
# 999    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# Name: Jobseek, Length: 1000, dtype: object

# %%
survey_df.rename(columns = {'Jobseek': 'jobseek'}, inplace=True)

# %%
survey_df['jobseek']
# Out:
# 0      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 1      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 2      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 3      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 4      I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
#                              ...
# 995    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# 996         I AM NOT INTERESTED IN NEW JOB OPPORTUNITIES
# 997                                                  NaN
# 998                      I AM ACTIVELY LOOKING FOR A JOB
# 999    I’M NOT ACTIVELY LOOKING, BUT I AM OPEN TO NEW...
# Name: jobseek, Length: 1000, dtype: object

# %%
survey_df.columns.str.lower()
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
survey_df.columns
# Out:
# Index(['Respondent', 'Mainbranch', 'Hobbyist', 'User_age', 'Age1stcode',
#        'Compfreq', 'Comptotal', 'Convertedcomp', 'Country', 'Currencydesc',
#        'Currencysymbol', 'Databasedesirenextyear', 'Databaseworkedwith',
#        'Devtype', 'Edlevel', 'Employment', 'Ethnicity', 'Gender', 'Jobfactors',
#        'Jobsat', 'jobseek', 'Languagedesirenextyear', 'Languageworkedwith',
#        'Misctechdesirenextyear', 'Misctechworkedwith',
#        'Newcollabtoolsdesirenextyear', 'Newcollabtoolsworkedwith', 'Newdevops',
#        'Newdevopsimpt', 'Newedimpt', 'Newjobhunt', 'Newjobhuntresearch',
#        'Newlearn', 'Newofftopic', 'Newonboardgood', 'Newothercomms',
#        'Newovertime', 'Newpurchaseresearch', 'Newpurplelink', 'Newsosites',
#        'Newstuck', 'Opsys', 'Organization_size', 'Platformdesirenextyear',
#        'Platformworkedwith', 'Purchasewhat', 'Sexuality', 'Soaccount',
#        'Socomm', 'Sopartfreq', 'Sovisitfreq', 'Surveyease', 'Surveylength',
# ...

# %%
survey_df.columns = survey_df.columns.str.lower()
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
survey_df.loc[2, 'trans']
# Out:
# 'Yes'

# %%
survey_df.loc[2, 'trans'] = 'Yes'
# 将index为2的数据上的trans列改为Yes

# %%
survey_df.loc[2, 'trans']
# Out:
# 'Yes'

# %%
survey_df.loc[2, ['trans', 'user_age', 'country']]  = ['Yes', 29, 'China'] 
# 将特定行的三列数据进行改变
survey_df.loc[2, ['trans', 'user_age', 'country']]
# Out:
# trans         Yes
# user_age     29.0
# country     China
# Name: 2, dtype: object

# %%
survey_df.loc[survey_df['user_age'] < 18, ['age_group']] = 'young'
# 创建一个age_group列，对于那些年龄小于18的用户，将此列的数据改为为 young

# %%
survey_df['age_group']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 995    NaN
# 996    NaN
# 997    NaN
# 998    NaN
# 999    NaN
# Name: age_group, Length: 1000, dtype: object

# %%
survey_df.loc[survey_df['user_age'] > 18, ['age_group']] = 'adult'
# 创建一个age_group列，对于那些年龄大于18的用户，将此列的数据改为为 adult

# %%
survey_df['age_group']
# Out:
# 0        NaN
# 1      adult
# 2      adult
# 3      adult
# 4      adult
#        ...
# 995    adult
# 996      NaN
# 997      NaN
# 998      NaN
# 999    adult
# Name: age_group, Length: 1000, dtype: object

# %%
survey_df['age_group'].count()
# Out:
# 692

# %%
survey_df['gender'] + survey_df['sexuality'] + survey_df['trans'] # 将性别相关的列合在一起
# Out:
# 0                                NaN
# 1                                NaN
# 2      ManStraight / HeterosexualYes
# 3                                NaN
# 4       ManStraight / HeterosexualNo
#                    ...
# 995     ManStraight / HeterosexualNo
# 996                              NaN
# 997                              NaN
# 998                              NaN
# 999     ManStraight / HeterosexualNo
# Length: 1000, dtype: object

# %%
survey_df['gen_col'] = survey_df['gender'] + survey_df['sexuality'] + survey_df['trans'] # 将合起来的值写入gen_col列

# %%
survey_df
# Out:
#      respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      29.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df['job_factors'] = survey_df['jobfactors'].str.split(';') # 根据符号 ; 进行分割
survey_df
# Out:
#      respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      29.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df['job_factors']
# Out:
# 0      [Industry that I’d be working in, Flex time or...
# 1      [Industry that I’d be working in, Flex time or...
# 2      [Industry that I’d be working in, Languages, f...
# 3      [Languages, frameworks, and other technologies...
# 4      [Industry that I’d be working in, Flex time or...
#                              ...
# 995    [Flex time or a flexible schedule, Languages, ...
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999    [Languages, frameworks, and other technologies...
# Name: job_factors, Length: 1000, dtype: object

# %%
for factors in survey_df['job_factors']:
    print(factors)
# Out:
# ['Industry that I’d be working in', 'Flex time or a flexible schedule', 'Languages, frameworks, and other technologies I’d be working with']
# ['Industry that I’d be working in', 'Flex time or a flexible schedule', 'Office environment or company culture']
# ['Industry that I’d be working in', 'Languages, frameworks, and other technologies I’d be working with', 'Office environment or company culture']
# ['Languages, frameworks, and other technologies I’d be working with', 'Specific department or team I’d be working on', 'Opportunities for professional development']
# ['Industry that I’d be working in', 'Flex time or a flexible schedule', 'Office environment or company culture']
# ['Flex time or a flexible schedule', 'Remote work options', 'Opportunities for professional development']
# ['Flex time or a flexible schedule', 'Languages, frameworks, and other technologies I’d be working with', 'Opportunities for professional development']
# ...

# %%
survey_df['jobfactors'].str.split(';', expand = True) # 将分隔开的内容分成多列
# Out:
#                                                      0  \
# 0                      Industry that I’d be working in
# 1                      Industry that I’d be working in
# 2                      Industry that I’d be working in
# 3    Languages, frameworks, and other technologies ...
# 4                      Industry that I’d be working in
# ..                                                 ...
# 995                   Flex time or a flexible schedule
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999  Languages, frameworks, and other technologies ...
#
#                                                      1  \
# 0                     Flex time or a flexible schedule
# 1                     Flex time or a flexible schedule
# 2    Languages, frameworks, and other technologies ...
# 3        Specific department or team I’d be working on
# ...

# %%
survey_df[['job_fac1', 'job_fac2', 'job_fac3']] = survey_df['jobfactors'].str.split(';', expand = True)

# %%
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
## survey_df.append({'user_age': 21}, ignore_index = True)
# 执行失败，DataFrame没有append函数

# %%
survey_df['job_fac1']
# Out:
# 0                        Industry that I’d be working in
# 1                        Industry that I’d be working in
# 2                        Industry that I’d be working in
# 3      Languages, frameworks, and other technologies ...
# 4                        Industry that I’d be working in
#                              ...
# 995                     Flex time or a flexible schedule
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999    Languages, frameworks, and other technologies ...
# Name: job_fac1, Length: 1000, dtype: object

# %%
survey_df.drop(columns = ['job_fac1'], inplace = True)

# %%
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
survey_df.head()
# Out:
#    respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0       20900  I am a developer by profession      Yes       NaN         10
# 1       28235  I am a developer by profession       No      45.0         10
# 2       26082  I am a developer by profession      Yes      29.0         14
# 3       19890  I am a developer by profession      Yes      61.0         21
# 4       16393  I am a developer by profession      Yes      25.0         15
#
#   compfreq  comptotal  convertedcomp   country          currencydesc  ...  \
# 0  Monthly     8000.0        53040.0  Bulgaria         Bulgarian lev  ...
# 1  Monthly   670000.0       867480.0    Norway       Norwegian krone  ...
# 2   Yearly    65000.0        65000.0     China  United States dollar  ...
# 3      NaN        NaN            NaN    Canada       Canadian dollar  ...
# 4   Weekly        NaN            NaN   Uruguay        Uruguayan peso  ...
#
#                             webframeworkedwith  \
# ...

# %%
survey_df.iloc[4]
# Out:
# respondent                                                 16393
# mainbranch                        I am a developer by profession
# hobbyist                                                     Yes
# user_age                                                    25.0
# age1stcode                                                    15
#                                      ...
# age_group                                                  adult
# gen_col                             ManStraight / HeterosexualNo
# job_factors    [Industry that I’d be working in, Flex time or...
# job_fac2                        Flex time or a flexible schedule
# job_fac3                   Office environment or company culture
# Name: 4, Length: 66, dtype: object

# %%
survey_df.drop(index = 4, inplace = True)
survey_df.head(5)
# Out:
#    respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0       20900  I am a developer by profession      Yes       NaN         10
# 1       28235  I am a developer by profession       No      45.0         10
# 2       26082  I am a developer by profession      Yes      29.0         14
# 3       19890  I am a developer by profession      Yes      61.0         21
# 5       46721  I am a developer by profession       No      48.0         11
#
#   compfreq  comptotal  convertedcomp      country          currencydesc  ...  \
# 0  Monthly     8000.0        53040.0     Bulgaria         Bulgarian lev  ...
# 1  Monthly   670000.0       867480.0       Norway       Norwegian krone  ...
# 2   Yearly    65000.0        65000.0        China  United States dollar  ...
# 3      NaN        NaN            NaN       Canada       Canadian dollar  ...
# 5   Yearly   130000.0        83057.0  New Zealand    New Zealand dollar  ...
#
# ...

# %%
survey_df['user_age']
# Out:
# 0       NaN
# 1      45.0
# 2      29.0
# 3      61.0
# 5      48.0
#        ...
# 995    26.0
# 996     NaN
# 997     NaN
# 998     NaN
# 999    29.0
# Name: user_age, Length: 999, dtype: float64

# %%
age_filter = survey_df['user_age'] < 50

# %%
age_filter
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 5       True
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: user_age, Length: 999, dtype: bool

# %%
age_filter.count()
# Out:
# 999

# %%
survey_df[age_filter]
# Out:
#      respondent                              mainbranch hobbyist  user_age  \
# 1         28235          I am a developer by profession       No      45.0
# 2         26082          I am a developer by profession      Yes      29.0
# 5         46721          I am a developer by profession       No      48.0
# 6         26832          I am a developer by profession      Yes      34.0
# 7         35682          I am a developer by profession      Yes      37.0
# ..          ...                                     ...      ...       ...
# 991       32771             I code primarily as a hobby      Yes      29.0
# 993        4528  I am a student who is learning to code      Yes      34.0
# 994       10977          I am a developer by profession      Yes      30.0
# 995       51360          I am a developer by profession      Yes      26.0
# 999       51843          I am a developer by profession      Yes      29.0
#
# ...

# %%
survey_df[age_filter].index
# Out:
# Index([  1,   2,   5,   6,   7,   8,   9,  10,  12,  13,
#        ...
#        985, 986, 987, 989, 990, 991, 993, 994, 995, 999],
#       dtype='int64', length=662)

# %%
survey_df.drop(survey_df[age_filter].index) #删除满足特定条件的数据
# Out:
#      respondent                                         mainbranch hobbyist  \
# 0         20900                     I am a developer by profession      Yes
# 3         19890                     I am a developer by profession      Yes
# 11        63975                     I am a developer by profession       No
# 15        42246                     I am a developer by profession       No
# 22        52375  I am not primarily a developer, but I write co...      Yes
# ..          ...                                                ...      ...
# 988         275                     I am a developer by profession       No
# 992       63802                     I am a developer by profession      Yes
# 996       16771                     I am a developer by profession      Yes
# 997       38831                     I am a developer by profession      Yes
# 998        7093                     I am a developer by profession      Yes
#
# ...

# %%
#学完了基本的数据更新和查询，接下来学习一下如何使用4个特别的函数（apply，map，applymap，replace）对DataFrame的数据进行更灵活的操作。

# %%
survey_df.dtypes
# Out:
# respondent       int64
# mainbranch      object
# hobbyist        object
# user_age       float64
# age1stcode      object
#                 ...
# age_group       object
# gen_col         object
# job_factors     object
# job_fac2        object
# job_fac3        object
# Length: 66, dtype: object

# %%
dtypes = survey_df.dtypes
dtypes.index
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
str_cols = [col_name for col_name in dtypes.index if dtypes[col_name] == 'object']

# %%
survey_df[str_cols] = survey_df[str_cols].astype(str)

# %%
survey_df.dtypes
# Out:
# respondent       int64
# mainbranch      object
# hobbyist        object
# user_age       float64
# age1stcode      object
#                 ...
# age_group       object
# gen_col         object
# job_factors     object
# job_fac2        object
# job_fac3        object
# Length: 66, dtype: object

# %%
survey_df['hobbyist'].apply(len)
# 查看这列数据的字符长度
# Out:
# 0      3
# 1      2
# 2      3
# 3      3
# 5      2
#       ..
# 995    3
# 996    3
# 997    3
# 998    3
# 999    3
# Name: hobbyist, Length: 999, dtype: int64

# %%
def upper_case(col_value):
     return col_value.upper()

# %%
survey_df['hobbyist'] = survey_df['hobbyist'].apply(upper_case) # 将此列的数据全部变成大写
survey_df['hobbyist']
# Out:
# 0      YES
# 1       NO
# 2      YES
# 3      YES
# 5       NO
#       ...
# 995    YES
# 996    YES
# 997    YES
# 998    YES
# 999    YES
# Name: hobbyist, Length: 999, dtype: object

# %%
survey_df['hobbyist'] = survey_df['hobbyist'].apply(lambda x: x.lower()) # 使用匿名函数将此列数据全部变成小写
survey_df['hobbyist']
# Out:
# 0      yes
# 1       no
# 2      yes
# 3      yes
# 5       no
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    yes
# Name: hobbyist, Length: 999, dtype: object

# %%
survey_df.apply(len)
# 查看每列的长度（有多少行）
# Out:
# respondent     999
# mainbranch     999
# hobbyist       999
# user_age       999
# age1stcode     999
#               ...
# age_group      999
# gen_col        999
# job_factors    999
# job_fac2       999
# job_fac3       999
# Length: 66, dtype: int64

# %%
survey_df.apply(len, axis = 'columns')
# 查看每行的长度（有多少列）
# Out:
# 0      66
# 1      66
# 2      66
# 3      66
# 5      66
#        ..
# 995    66
# 996    66
# 997    66
# 998    66
# 999    66
# Length: 999, dtype: int64

# %%
survey_df.apply(pd.Series.min) # 查看每列中最小的元素
# Out:
# respondent                                                    59
# mainbranch                        I am a developer by profession
# hobbyist                                                     nan
# user_age                                                    13.0
# age1stcode                                                    10
#                                      ...
# age_group                                                  adult
# gen_col        Man;Non-binary, genderqueer, or gender non-con...
# job_factors    ['Diversity of the company or organization', '...
# job_fac2                Diversity of the company or organization
# job_fac3                                     Family friendliness
# Length: 66, dtype: object

# %%
survey_df.apply(lambda x: x.min()) # 其中 x 代表一个Series，此行代码也能拿到每列中最小的数值
# Out:
# respondent                                                    59
# mainbranch                        I am a developer by profession
# hobbyist                                                     nan
# user_age                                                    13.0
# age1stcode                                                    10
#                                      ...
# age_group                                                  adult
# gen_col        Man;Non-binary, genderqueer, or gender non-con...
# job_factors    ['Diversity of the company or organization', '...
# job_fac2                Diversity of the company or organization
# job_fac3                                     Family friendliness
# Length: 66, dtype: object

# %%
map_dict = {'yes': 'True', 'no': 'False'}
survey_df['hobbyist'].map(map_dict) # 将yes转为True，no转为False，不match的变成NaN
#map只能用于Series：
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 5      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: hobbyist, Length: 999, dtype: object

# %%
# map主要是针对Series的，那apply和map合起来的applymap则是针对每一个数据的：
survey_df[str_cols].applymap(len) # 针对于每个元素，对每个str数据类型的数据使用len函数

#####DataFrame.applymap has been deprecated. Use DataFrame.map instead.########
#英不再支持applymap，直接用map就好。
# Out:
# /var/folders/8x/mqksqpls3zqbwj71jz54jj8c0000gn/T/ipykernel_78111/2813973773.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   survey_df[str_cols].applymap(len) # 针对于每个元素，对每个str数据类型的数据使用len函数
#      mainbranch  hobbyist  age1stcode  compfreq  country  currencydesc  \
# 0            30         3           2         7        8            13
# 1            30         2           2         7        6            15
# 2            30         3           2         6        5            20
# 3            30         3           2         3        6            15
# 5            30         2           2         6       11            18
# ..          ...       ...         ...       ...      ...           ...
# 995          30         3           2         7        5            14
# 996          30         3           2         3       13            20
# 997          30         3           3         3       11             3
# ...

# %%
map_dict = {'yes': 'True'}
survey_df['hobbyist'].replace(map_dict) # yes 会变成 True，其他保持不变
# Out:
# 0      True
# 1        no
# 2      True
# 3      True
# 5        no
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: hobbyist, Length: 999, dtype: object

# %%
survey_df['hobbyist'].map(map_dict) # no 和 nan 都会变成 NaN
# Out:
# 0      True
# 1       NaN
# 2      True
# 3      True
# 5       NaN
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: hobbyist, Length: 999, dtype: object

# %%
survey_df.head()
# Out:
#    respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0       20900  I am a developer by profession      yes       NaN         10
# 1       28235  I am a developer by profession       no      45.0         10
# 2       26082  I am a developer by profession      yes      29.0         14
# 3       19890  I am a developer by profession      yes      61.0         21
# 5       46721  I am a developer by profession       no      48.0         11
#
#   compfreq  comptotal  convertedcomp      country          currencydesc  ...  \
# 0  Monthly     8000.0        53040.0     Bulgaria         Bulgarian lev  ...
# 1  Monthly   670000.0       867480.0       Norway       Norwegian krone  ...
# 2   Yearly    65000.0        65000.0        China  United States dollar  ...
# 3      nan        NaN            NaN       Canada       Canadian dollar  ...
# 5   Yearly   130000.0        83057.0  New Zealand    New Zealand dollar  ...
#
# ...

# %%
survey_df.iloc[[3], [6]]
# Out:
#    comptotal
# 3        NaN

# %%
survey_df.iloc[[3], [6]] = '11111'

# %%
survey_df.iloc[[3], [6]]
# Out:
#   comptotal
# 3     11111

# %%
#Homework
#找出所有以编程为兴趣，并且年龄小于25岁的用户。
#在原来的dataframe中给这些特定用户新添一个column叫做code_years，这列的值等于user_age – age1stcode

# %%
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
# ...

# %%
age_filter = survey_df['user_age'] < 25

# %%
age_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: user_age, Length: 999, dtype: bool

# %%
len(age_filter)
# Out:
# 999

# %%
age_filter.count()
# Out:
# 999

# %%
age_filter.head(20)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# Name: user_age, dtype: bool

# %%
survey_df.head()
# Out:
#    respondent                      mainbranch hobbyist  user_age age1stcode  \
# 0       20900  I am a developer by profession      yes       NaN         10
# 1       28235  I am a developer by profession       no      45.0         10
# 2       26082  I am a developer by profession      yes      29.0         14
# 3       19890  I am a developer by profession      yes      61.0         21
# 5       46721  I am a developer by profession       no      48.0         11
#
#   compfreq comptotal  convertedcomp      country          currencydesc  ...  \
# 0  Monthly    8000.0        53040.0     Bulgaria         Bulgarian lev  ...
# 1  Monthly  670000.0       867480.0       Norway       Norwegian krone  ...
# 2   Yearly   65000.0        65000.0        China  United States dollar  ...
# 3      nan     11111            NaN       Canada       Canadian dollar  ...
# 5   Yearly  130000.0        83057.0  New Zealand    New Zealand dollar  ...
#
#                             webframeworkedwith  \
# ...

# %%
survey_df.iloc[1]
# Out:
# respondent                                                 28235
# mainbranch                        I am a developer by profession
# hobbyist                                                      no
# user_age                                                    45.0
# age1stcode                                                    10
#                                      ...
# age_group                                                  adult
# gen_col                                                      nan
# job_factors    ['Industry that I’d be working in', 'Flex time...
# job_fac2                        Flex time or a flexible schedule
# job_fac3                   Office environment or company culture
# Name: 1, Length: 66, dtype: object

# %%
survey_df['hobbyist']
# Out:
# 0      yes
# 1       no
# 2      yes
# 3      yes
# 5       no
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    yes
# Name: hobbyist, Length: 999, dtype: object

# %%
hob_list = survey_df['hobbyist'] == 'yes'

# %%
hob_list
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 5      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: hobbyist, Length: 999, dtype: bool

# %%
data_filter = hob_list & age_filter

# %%
data_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 999, dtype: bool

# %%
filter_data = survey_df.loc[data_filter]
survey_df.loc[data_filter, 'code_years'] = filter_data['user_age'] - filter_data['age1stcode'].astype(int)

# %%
survey_df.loc[data_filter, 'code_years']
# Out:
# 8      11.0
# 12      9.0
# 20      6.0
# 32     13.0
# 54      6.0
#        ...
# 951     6.0
# 965     9.0
# 966     6.0
# 977    15.0
# 978     3.0
# Name: code_years, Length: 152, dtype: float64
